# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pick= pd.read_csv('/content/drive/MyDrive/cleaned_pickup_data.csv')

# %%
pick.head()
# Out:
#    order_id  region_id  city  courier_id          accept_time  \
# 0  0.078492   0.022388     0    0.094485  1900-08-14 07:57:00
# 1  0.283371   0.022388     0    0.292917  1900-10-09 07:46:00
# 2  0.373535   0.022388     0    0.292917  1900-10-09 13:57:00
# 3  0.614853   0.022388     0    0.292917  1900-05-19 08:13:00
# 4  0.115780   0.022388     0    0.292917  1900-05-22 08:16:00
#
#   time_window_start time_window_end       lng       lat    aoi_id  ...  \
# 0        2000-01-01      2000-01-01  0.043854  0.036271  0.008882  ...
# 1        2000-01-01      2000-01-01  0.043852  0.036268  0.008882  ...
# 2        2000-01-01      2000-01-01  0.043851  0.036262  0.008882  ...
# 3        2000-01-01      2000-01-01  0.043854  0.036273  0.008882  ...
# 4        2000-01-01      2000-01-01  0.043828  0.036286  0.008882  ...
#
#    pickup_gps_lng pickup_gps_lat                accept_gps_time  \
# 0        0.633048       0.489546  1900-07-31 15:21:47.527556864
# 1        0.633048       0.489546  1900-07-31 15:21:47.527556864
# 2        0.157003       0.368339  1900-10-09 13:56:00.000000000
# 3        0.633048       0.489546  1900-07-31 15:21:47.527556864
# 4        0.157005       0.368533  1900-07-31 15:21:47.527556864
#
#    accept_gps_lng  accept_gps_lat                             ds  \
# 0        0.636678        0.438709  1970-01-01 00:00:00.000000814
# 1        0.636678        0.438709  1970-01-01 00:00:00.000001009
# 2        0.156368        0.298870  1970-01-01 00:00:00.000001009
# 3        0.636678        0.438709  1970-01-01 00:00:00.000000519
# 4        0.636678        0.438709  1970-01-01 00:00:00.000000522
#
#    time_window_duration  task_duration   distance  \
# 0                   0.0         6060.0   0.203825
# 1                   0.0         6960.0   0.203825
# 2                   0.0         6960.0   0.004725
# 3                   0.0        13560.0   0.203825
# 4                   0.0         8640.0  12.497969
#
#                      pi_gps_time
# 0  1900-08-01 16:57:58.148008960
# 1  1900-08-01 16:57:58.148008960
# 2  1900-10-09 15:53:00.000000000
# 3  1900-08-01 16:57:58.148008960
# 4  1900-05-22 10:40:00.000000000
#
# [5 rows x 23 columns]

# %%
pick.isnull().sum()
# Out:
# order_id                0
# region_id               0
# city                    0
# courier_id              0
# accept_time             0
# time_window_start       0
# time_window_end         0
# lng                     0
# lat                     0
# aoi_id                  0
# aoi_type                0
# pickup_time             0
# pickup_gps_time         0
# pickup_gps_lng          0
# pickup_gps_lat          0
# accept_gps_time         0
# accept_gps_lng          0
# accept_gps_lat          0
# ds                      0
# time_window_duration    0
# task_duration           0
# distance                0
# pi_gps_time             0
# dtype: int64

# %%
pick.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5202878 entries, 0 to 5202877
# Data columns (total 23 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   order_id              float64
#  1   region_id             float64
#  2   city                  int64
#  3   courier_id            float64
#  4   accept_time           object
#  5   time_window_start     object
#  6   time_window_end       object
#  7   lng                   float64
#  8   lat                   float64
#  9   aoi_id                float64
#  10  aoi_type              int64
#  11  pickup_time           object
#  12  pickup_gps_time       object
#  13  pickup_gps_lng        float64
#  14  pickup_gps_lat        float64
#  15  accept_gps_time       object
#  16  accept_gps_lng        float64
#  17  accept_gps_lat        float64
#  18  ds                    object
#  19  time_window_duration  float64
#  20  task_duration         float64
#  21  distance              float64
#  22  pi_gps_time           object
# dtypes: float64(13), int64(2), object(8)
# memory usage: 913.0+ MB

# %%
time_columns = ['accept_time','time_window_start','time_window_end','pickup_time','pickup_gps_time','accept_gps_time','ds','pi_gps_time']

for col in time_columns:
    pick[col] = pd.to_datetime(pick[col],errors='coerce')

# %%
pick['hour'] = pick['pickup_time'].dt.hour
pick['day'] = pick['pickup_time'].dt.day
pick['month'] = pick['pickup_time'].dt.month
pick['weekday'] = pick['pickup_time'].dt.weekday  # Monday=0, Sunday=6
pick['is_weekend'] = pick['weekday'].apply(lambda x: 1 if x >= 5 else 0)

# %%
pick['task_duration']=pick['task_duration']/60

# %%
pick.shape
# Out:
# (5202878, 28)

# %%
numerical_cols = pick.select_dtypes(include=np.number).columns

# %%
for col in numerical_cols:
    plt.figure(figsize=(4, 3))
    sns.histplot(pick[col], kde=True)
    plt.title(f'{col}')
    plt.show()

# %%
for col in numerical_cols:
    plt.figure(figsize=(8, 5))
    sns.boxplot(pick[col], palette='pastel')
    plt.title(f'Box Plot of {col}')
    plt.show()
# Out:
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')
# <ipython-input-36-9c594f489795>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(pick[col], palette='pastel')

# %%
sns.scatterplot(data=pick, x='distance', y='task_duration', hue='region_id', palette='coolwarm')
plt.title(' distance vs task_duration ')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Correlation Matrix (numerical features only)
corr_matrix = pick[numerical_cols].corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.show()

# %%
numerical_features=['city','region_id','task_duration','distance']

# %%
sns.pairplot(pick[numerical_features])
plt.show()

# %%
numerical_features_2=['region_id','task_duration','distance']
scaler = StandardScaler()

scaled_pick= scaler.fit_transform(pick[numerical_features_2])

# PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_pick)

print(f'Explained Variance Ratio: {pca.explained_variance_ratio_}')
# Out:
# Explained Variance Ratio: [0.3658014 0.3432155]

# %%
# Scatter plot of PCA results
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=pick['region_id'], cmap='viridis')
plt.colorbar()
plt.title('PCA Result')
plt.show()
